# %%
import re

import pandas as pd
import torch
from openai import OpenAI
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
saq = pd.read_csv("../data/train_dataset_saq.csv")

print(len(saq))

val_saq = saq.sample(n=200, random_state=42) # 667 is the maximal number of test-samples
train_saq = saq.drop(val_saq.index)
#saq = saq[["ID", "en_question"]]

# %%
print(len(saq))
print(len(val_saq))
print(len(train_saq))

# %%
val_saq["ID"].nunique()

# %%
train_saq["ID"].nunique()

# %%
val_saq

# %%
val_saq.to_csv("../data/val_split_saq.csv", index=False)
train_saq.to_csv("../data/train_split_saq.csv", index=False)

# %%
mcq = pd.read_csv("../data/train_dataset_mcq.csv")

print(len(mcq))

val_mcq = mcq.sample(n=125, random_state=42)
train_mcq = mcq.drop(val_mcq.index)

# %%
print(len(mcq))
print(len(val_mcq))
print(len(train_mcq))

# %%
val_mcq.to_csv("../data/val_split_mcq.csv", index=False)
train_mcq.to_csv("../data/train_split_mcq.csv", index=False)

# %%
val_mcq["ID"].nunique()

# %%
train_mcq["ID"].nunique()
